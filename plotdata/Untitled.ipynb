# %%
from obspy import read
import matplotlib.pyplot as plt
plt.style.use('seaborn');

# %%
threechannels = read('https://examples.obspy.org/COP.BHE.DK.2009.050')
threechannels += read('https://examples.obspy.org/COP.BHN.DK.2009.050')
threechannels += read('https://examples.obspy.org/COP.BHZ.DK.2009.050')

# %%
threechannels.plot(size=(800, 600))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17672/2797562320.py in <module>
# ----> 1 threechannels.plot(size=(800, 600))
#
# ~\anaconda3\envs\AIML\lib\site-packages\obspy\core\stream.py in plot(self, *args, **kwargs)
#    1159         from obspy.imaging.waveform import WaveformPlotting
#    1160         waveform = WaveformPlotting(stream=self, *args, **kwargs)
# -> 1161         return waveform.plot_waveform(*args, **kwargs)
#    1162
#    1163     def spectrogram(self, **kwargs):
#
# ~\anaconda3\envs\AIML\lib\site-packages\obspy\imaging\waveform.py in plot_waveform(self, *args, **kwargs)
#     276             self.plot_section(*args, **kwargs)
#     277         else:
# --> 278             self.plot(*args, **kwargs)
#     279         # Adjust the subplot so there is always a fixed margin on every side
#     280         if self.type != 'dayplot':
#
# ~\anaconda3\envs\AIML\lib\site-packages\obspy\imaging\waveform.py in plot(self, *args, **kwargs)
#     401                 self.__plot_straight(stream_new[_i], ax, *args, **kwargs)
#     402             elif method_ == 'fast':
# --> 403                 self.__plot_min_max(stream_new[_i], ax, *args, **kwargs)
#     404             else:
#     405                 msg = "Invalid plot method: '%s'" % method_
#
# ~\anaconda3\envs\AIML\lib\site-packages\obspy\imaging\waveform.py in __plot_min_max(self, trace, ax, *args, **kwargs)
#     766             # Calculate extreme_values and put them into new array.
#     767             if remaining_samples:
# --> 768                 extreme_values = np.empty((pixel_count + 1, 2), dtype=np.float)
#     769                 extreme_values[:-1, 0] = min_
#     770                 extreme_values[:-1, 1] = max_
#
# ~\anaconda3\envs\AIML\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     303
#     304         if attr in __former_attrs__:
# --> 305             raise AttributeError(__former_attrs__[attr])
#     306
#     307         # Importing Tester requires importing all of UnitTest which is not a
#
# AttributeError: module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
